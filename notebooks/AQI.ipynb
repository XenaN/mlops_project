# %%
import sys
sys.version
# Out:
# '3.9.12 (main, May  5 2022, 20:10:55) \n[GCC 7.5.0]'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
country = 'ES'

# %%
df_co = pd.read_csv(f"../data/interim/cleaned/{country}_CO_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
df_co
# Out:
#                           Countrycode    Namespace AirQualityNetwork  \
# Datetime
# 2020-01-01 01:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2020-01-01 02:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2020-01-01 03:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2020-01-01 04:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2020-01-01 05:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# ...                               ...          ...               ...
# 2022-05-19 00:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-05-19 01:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-05-19 02:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-05-19 03:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-05-19 04:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
#
#                           AirQualityStation AirQualityStationEoICode  \
# Datetime
# 2020-01-01 01:00:00+01:00       STA_ES1563A                  ES1563A
# 2020-01-01 02:00:00+01:00       STA_ES1563A                  ES1563A
# 2020-01-01 03:00:00+01:00       STA_ES1563A                  ES1563A
# 2020-01-01 04:00:00+01:00       STA_ES1563A                  ES1563A
# 2020-01-01 05:00:00+01:00       STA_ES1563A                  ES1563A
# ...                                     ...                      ...
# 2022-05-19 00:00:00+01:00       STA_ES1563A                  ES1563A
# 2022-05-19 01:00:00+01:00       STA_ES1563A                  ES1563A
# 2022-05-19 02:00:00+01:00       STA_ES1563A                  ES1563A
# 2022-05-19 03:00:00+01:00       STA_ES1563A                  ES1563A
# 2022-05-19 04:00:00+01:00       STA_ES1563A                  ES1563A
#
#                               SamplingPoint      SamplingProcess  \
# Datetime
# 2020-01-01 01:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
# 2020-01-01 02:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
# 2020-01-01 03:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
# 2020-01-01 04:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
# 2020-01-01 05:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
# ...                                     ...                  ...
# 2022-05-19 00:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
# 2022-05-19 01:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
# 2022-05-19 02:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
# 2022-05-19 03:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
# 2022-05-19 04:00:00+01:00  SP_28005002_6_48  SPP_28005002_6_48.1
#
#                                       Sample AirPollutant  \
# Datetime
# 2020-01-01 01:00:00+01:00  SAM_28005002_6_48           CO
# 2020-01-01 02:00:00+01:00  SAM_28005002_6_48           CO
# 2020-01-01 03:00:00+01:00  SAM_28005002_6_48           CO
# 2020-01-01 04:00:00+01:00  SAM_28005002_6_48           CO
# 2020-01-01 05:00:00+01:00  SAM_28005002_6_48           CO
# ...                                      ...          ...
# 2022-05-19 00:00:00+01:00  SAM_28005002_6_48           CO
# 2022-05-19 01:00:00+01:00  SAM_28005002_6_48           CO
# 2022-05-19 02:00:00+01:00  SAM_28005002_6_48           CO
# 2022-05-19 03:00:00+01:00  SAM_28005002_6_48           CO
# 2022-05-19 04:00:00+01:00  SAM_28005002_6_48           CO
#
#                                                             AirPollutantCode  \
# Datetime
# 2020-01-01 01:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
# 2020-01-01 02:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
# 2020-01-01 03:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
# 2020-01-01 04:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
# 2020-01-01 05:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
# ...                                                                      ...
# 2022-05-19 00:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
# 2022-05-19 01:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
# 2022-05-19 02:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
# 2022-05-19 03:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
# 2022-05-19 04:00:00+01:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
#
#                           AveragingTime  Concentration UnitOfMeasurement  \
# Datetime
# 2020-01-01 01:00:00+01:00          hour            0.7             mg/m3
# 2020-01-01 02:00:00+01:00          hour            0.9             mg/m3
# 2020-01-01 03:00:00+01:00          hour            0.8             mg/m3
# 2020-01-01 04:00:00+01:00          hour            0.6             mg/m3
# 2020-01-01 05:00:00+01:00          hour            0.6             mg/m3
# ...                                 ...            ...               ...
# 2022-05-19 00:00:00+01:00          hour            0.2             mg/m3
# 2022-05-19 01:00:00+01:00          hour            0.2             mg/m3
# 2022-05-19 02:00:00+01:00          hour            0.2             mg/m3
# 2022-05-19 03:00:00+01:00          hour            NaN             mg/m3
# 2022-05-19 04:00:00+01:00          hour            NaN             mg/m3
#
#                                         DatetimeBegin  \
# Datetime
# 2020-01-01 01:00:00+01:00  2020-01-01 00:00:00 +01:00
# 2020-01-01 02:00:00+01:00  2020-01-01 01:00:00 +01:00
# 2020-01-01 03:00:00+01:00  2020-01-01 02:00:00 +01:00
# 2020-01-01 04:00:00+01:00  2020-01-01 03:00:00 +01:00
# 2020-01-01 05:00:00+01:00  2020-01-01 04:00:00 +01:00
# ...                                               ...
# 2022-05-19 00:00:00+01:00  2022-05-18 23:00:00 +01:00
# 2022-05-19 01:00:00+01:00  2022-05-19 00:00:00 +01:00
# 2022-05-19 02:00:00+01:00  2022-05-19 01:00:00 +01:00
# 2022-05-19 03:00:00+01:00  2022-05-19 02:00:00 +01:00
# 2022-05-19 04:00:00+01:00  2022-05-19 03:00:00 +01:00
#
#                                           DatetimeEnd  Validity  Verification
# Datetime
# 2020-01-01 01:00:00+01:00  2020-01-01 01:00:00 +01:00         1             1
# 2020-01-01 02:00:00+01:00  2020-01-01 02:00:00 +01:00         1             1
# 2020-01-01 03:00:00+01:00  2020-01-01 03:00:00 +01:00         1             1
# 2020-01-01 04:00:00+01:00  2020-01-01 04:00:00 +01:00         1             1
# 2020-01-01 05:00:00+01:00  2020-01-01 05:00:00 +01:00         1             1
# ...                                               ...       ...           ...
# 2022-05-19 00:00:00+01:00  2022-05-19 00:00:00 +01:00         1             3
# 2022-05-19 01:00:00+01:00  2022-05-19 01:00:00 +01:00         1             3
# 2022-05-19 02:00:00+01:00  2022-05-19 02:00:00 +01:00         1             3
# 2022-05-19 03:00:00+01:00  2022-05-19 03:00:00 +01:00        -1             3
# 2022-05-19 04:00:00+01:00  2022-05-19 04:00:00 +01:00        -1             3
#
# [20860 rows x 17 columns]

# %%
fig = plt.figure(figsize=(15, 10))
df_co["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_no2 = pd.read_csv(f"../data/interim/cleaned/{country}_NO2_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_no2["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_o3 = pd.read_csv(f"../data/interim/cleaned/{country}_O3_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_o3["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_so2 = pd.read_csv(f"../data/interim/cleaned/{country}_SO2_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_so2["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_pm10 = pd.read_csv(f"../data/interim/cleaned/{country}_PM10_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_pm10["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_pm25 = pd.read_csv(f"../data/interim/cleaned/{country}_PM2.5_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_pm25["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_pm25["Concentration"].idxmax()
# Out:
# Timestamp('2022-03-15 09:00:00+0100', tz='pytz.FixedOffset(60)')

# %%
df_pm10["Concentration"].idxmax()
# Out:
# Timestamp('2022-03-15 09:00:00+0100', tz='pytz.FixedOffset(60)')

# %% [markdown]
# AQI

# %%
df_aqi = pd.read_csv("../data/processed/AQI_dataset.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_aqi["AQI"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_aqi_daily = df_aqi.resample('D').mean().interpolate()
fig = plt.figure(figsize=(15, 10))
df_aqi_daily["AQI"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %% [markdown]
# ***Time series analysis***

# %% [markdown]
# Stationarity

# %%
from statsmodels.tsa.stattools import adfuller
ADF_result = adfuller(df_aqi_daily["AQI"])   
print(f'ADF Statistic: {ADF_result[0]}') 
print(f'p-value: {ADF_result[1]}')
# Out:
# ADF Statistic: -10.640151095533533
# p-value: 4.953929224175729e-19

# %% [markdown]
# With a large negative ADF statistic and a p-value much smaller than 0.05, we can say that our series is stationary.

# %% [markdown]
# Autocorrelation

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(df_aqi_daily["AQI"], lags=50)
plt.tight_layout()

# %%
plot_pacf(df_aqi_daily["AQI"], lags=50)
plt.show()

# %% [markdown]
# Looks like autoregressive process

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

analysis = df_aqi_daily["AQI"].copy()


decompose_result_mult = seasonal_decompose(analysis, model="multiplicative")

trend = decompose_result_mult.trend
seasonal = decompose_result_mult.seasonal
residual = decompose_result_mult.resid

fig = plt.figure(figsize=(15, 10))
seasonal[:100].plot();

# %% [markdown]
# ***Baseline Naive Algorithm***

# %%
pd.concat([df_aqi_daily["AQI"].shift(1), df_aqi_daily["AQI"]], axis=1).dropna()
# Out:
#                                  AQI        AQI
# Datetime
# 2020-01-02 00:00:00+01:00  74.500000  76.208333
# 2020-01-03 00:00:00+01:00  76.208333  85.375000
# 2020-01-04 00:00:00+01:00  85.375000  81.791667
# 2020-01-05 00:00:00+01:00  81.791667  41.708333
# 2020-01-06 00:00:00+01:00  41.708333  59.916667
# ...                              ...        ...
# 2022-05-15 00:00:00+01:00  51.833333  47.458333
# 2022-05-16 00:00:00+01:00  47.458333  48.695652
# 2022-05-17 00:00:00+01:00  48.695652  37.916667
# 2022-05-18 00:00:00+01:00  37.916667  37.708333
# 2022-05-19 00:00:00+01:00  37.708333  38.000000
#
# [869 rows x 2 columns]

# %%
values = pd.DataFrame(df_aqi_daily["AQI"].values)
df_naive = pd.concat([values.shift(1), values], axis=1).dropna()
df_naive.columns = ['t-1', 't+1']
df_naive
# Out:
#            t-1        t+1
# 1    74.500000  76.208333
# 2    76.208333  85.375000
# 3    85.375000  81.791667
# 4    81.791667  41.708333
# 5    41.708333  59.916667
# ..         ...        ...
# 865  51.833333  47.458333
# 866  47.458333  48.695652
# 867  48.695652  37.916667
# 868  37.916667  37.708333
# 869  37.708333  38.000000
#
# [869 rows x 2 columns]

# %%
train_size = int(df_naive.shape[0] * 0.8)
train, test = df_naive[1:train_size], df_naive[train_size:]
train_X, train_y = train["t-1"], train["t+1"]
test_X, test_y = test["t-1"], test["t+1"]

# %%
predictions = test_X.apply(lambda x: x)
test_rmse = mean_squared_error(test_y, predictions, squared=False)
print('Test RMSE: %.3f' % test_rmse)
# Out:
# Test RMSE: 12.877

# %%
fig = plt.figure(figsize=(15, 10))
plt.plot(test_y.iloc[:])
plt.plot(predictions[:])
plt.show()

# %%
df_aqi_daily["AQI"].mean(), df_aqi_daily["AQI"].std(), df_aqi_daily["AQI"].median()
# Out:
# (45.8914567572062, 16.318590409788275, 42.6875)

# %% [markdown]
# ***One more model with several list of params***

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df_aqi_daily["AQI"], test_size=0.2, shuffle=False)

# %%
model = ARIMA(train, order=(2,0,0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    AQI   No. Observations:                  696
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -2587.056
# Date:                Thu, 19 May 2022   AIC                           5182.112
# Time:                        16:36:44   BIC                           5200.293
# Sample:                    01-01-2020   HQIC                          5189.142
#                          - 11-26-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         46.7974      1.517     30.852      0.000      43.824      49.770
# ar.L1          0.9590      0.030     31.474      0.000       0.899       1.019
# ar.L2         -0.2341      0.030     -7.901      0.000      -0.292      -0.176
# sigma2        98.9593      4.020     24.616      0.000      91.080     106.839
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.87   Jarque-Bera (JB):               209.11
# Prob(Q):                              0.35   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.73   Skew:                            -0.13
# Prob(H) (two-sided):                  0.02   Kurtosis:                         5.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predictions_p_ms = model_fit.predict(start=len(train), end=len(train)+5)

# %%
arima_test_rmse = mean_squared_error(test.iloc[:6], predictions_p_ms, squared=False)
print('Test RMSE: %.3f' % arima_test_rmse)
# Out:
# Test RMSE: 7.852

# %%
rmse_arima = []
n = 1
# train = train.values
for i in range(len(test)-n):
    model = ARIMA(train, order=(4,0,0))
    model_fit = model.fit()
    predictions_p_ms = model_fit.predict(start=len(train), end=len(train)+n)
    arima_test_rmse = mean_squared_error(test.iloc[i:i+n+1], predictions_p_ms, squared=False)
    rmse_arima.append(arima_test_rmse)
    
    train = np.append(train, test.iloc[0])

print("RMSE: {}".format(np.mean(rmse_arima)))

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test.iloc[:6], label='actual')
plt.plot(predictions_p_ms, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
train_size = int(df_naive.shape[0] * 0.8)
train, test = df_naive[1:train_size], df_naive[train_size:]
train_X, train_y = train["t-1"], train["t+1"]
test_X, test_y = test["t-1"], test["t+1"]

# %%
model_forest = RandomForestRegressor(n_estimators=1000)
model_forest.fit(train_X.values.reshape(-1, 1), train_y.values)

y_hat = model_forest.predict(np.array(test_X)[:, np.newaxis])

forest_test_rmse = mean_squared_error(test_y, y_hat, squared=False)

# %%
print(forest_test_rmse)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train["t-1"], label='training')
plt.plot(test["t-1"], label='actual')
plt.plot(test.index, y_hat, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# 14.105542434217508

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
tscv = TimeSeriesSplit()
TimeSeriesSplit(max_train_size=None, n_splits=5)
rmse = []
for train_index, test_index in tscv.split(df_naive):
    train_cv, test_cv = df_naive.iloc[train_index], df_naive.iloc[test_index]
    train_X_cv, train_y_cv = train_cv["t-1"], train_cv["t+1"]
    test_X_cv, test_y_cv = test_cv["t-1"], test_cv["t+1"]  
    
    model_forest_cv = RandomForestRegressor(n_estimators=1000)
    model_forest_cv.fit(train_X_cv.values.reshape(-1, 1), train_y_cv.values)

    y_hat_cv = model_forest_cv.predict(np.array(test_X_cv)[:, np.newaxis])

    rmse_cv = mean_squared_error(test_y_cv, y_hat_cv, squared=False)  
    rmse.append(rmse_cv)
    
    plt.figure(figsize=(12,5), dpi=100)
    plt.plot(train_cv["t-1"], label='training')
    plt.plot(test_cv["t-1"], label='actual')
    plt.plot(test_X_cv.index, y_hat_cv, label='forecast')
    plt.title('Forecast vs Actuals')
    plt.legend(loc='upper left', fontsize=8)
    plt.show()

print("RMSE: {}".format(np.mean(rmse)))
# Out:
# RMSE: 12.25566935341043

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 15)]
max_depth = [int(x) for x in np.linspace(10, 110, num = 15)]
max_depth.append(None)
min_samples_split = [2, 5, 8, 10]
min_samples_leaf = [2, 4, 6, 8]
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
tscv = TimeSeriesSplit(n_splits=3)
model_forest_cv = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = model_forest_cv, param_distributions = random_grid, 
                               n_iter = 500, cv = tscv, verbose=1, random_state=42, n_jobs = -1)

rf_random.fit(df_naive["t-1"].values.reshape(-1, 1), df_naive["t+1"].values)
# Out:
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                    estimator=RandomForestRegressor(), n_iter=500, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 17, 24, 31, 38, 45,
#                                                       52, 60, 67, 74, 81, 88,
#                                                       95, 102, 110, None],
#                                         'min_samples_leaf': [2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 8, 10],
#                                         'n_estimators': [200, 328, 457, 585,
#                                                          714, 842, 971, 1100,
#                                                          1228, 1357, 1485, 1614,
#                                                          1742, 1871, 2000]},
#                    random_state=42, verbose=1)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 585,
#  'min_samples_split': 2,
#  'min_samples_leaf': 8,
#  'max_depth': 52,
#  'bootstrap': True}

# %%
best_random = rf_random.best_estimator_
predictions = best_random.predict(np.array(test_X)[:, np.newaxis])
best_rmse = mean_squared_error(test_y, predictions, squared=False)

# %%
best_rmse
# Out:
# 12.39850863221307

# %%
params = {'n_estimators': 1000,
              'min_samples_split': 2,
              'min_samples_leaf': 8,
              'max_depth': 52,
              'bootstrap': True}

# %%
df_naive.tail(1)
# Out:
#            t-1   t+1
# 869  37.708333  38.0

# %%
rmse_f = {}
n = 1
train_n, test_n = df_naive[1:train_size], df_naive[train_size:]
for i in range(len(test)):
    train_X_n, train_y_n = train_n["t-1"], train_n["t+1"]
    test_X_n, test_y_n = test_n["t-1"], test_n["t+1"]
    model_forest_n = RandomForestRegressor(random_state=42, **params)
    model_forest_n.fit(train_X_n.values.reshape(-1, 1), train_y_n.values)
    y_hat_n = model_forest_n.predict(np.array(test_X_n.iloc[i:i+n])[:, np.newaxis])
    rmse_n = mean_squared_error(test_y_n.iloc[i:i+n], y_hat_n, squared=False)  
    rmse_f[f'{test_y_n.iloc[i:i+n].values}'] = rmse_n
    
    train_n = pd.concat([train_n, test_n.iloc[i:i+n]])

# print("RMSE: {}".format(np.mean(rmse_f)))

# %%
rmse_f
# Out:
# {'[27.16666667]': 4.130403890816886,
#  '[30.]': 3.4544139034074064,
#  '[28.29166667]': 4.601317484723349,
#  '[37.375]': 4.50736122779945,
#  '[58.54166667]': 20.323671969344375,
#  '[48.57142857]': 4.324644225435776,
#  '[31.08695652]': 17.17460697759255,
#  '[48.16666667]': 12.557474603001026,
#  '[33.91666667]': 4.202038837272802,
#  '[22.79166667]': 14.025947065236412,
#  '[32.5]': 1.6372811569589167,
#  '[34.]': 0.539973904229015,
#  '[23.95454545]': 11.535485673679723,
#  '[27.04166667]': 4.930987661411759,
#  '[28.5]': 4.7426679250345884,
#  '[39.25]': 6.68993413851571,
#  '[40.25]': 0.3537569520581698,
#  '[52.20833333]': 7.995959270694321,
#  '[56.75]': 5.9339153595323,
#  '[62.83333333]': 7.11494341164353,
#  '[61.13636364]': 0.48556873596823635,
#  '[58.41666667]': 5.209904163943982,
#  '[46.66666667]': 0.7759840732011014,
#  '[49.25]': 2.011242537206776,
#  '[58.95833333]': 13.28270273449126,
#  '[68.85714286]': 17.183895957488502,
#  '[51.04166667]': 17.42775705826282,
#  '[36.83333333]': 10.983383201138295,
#  '[22.25]': 18.149405517515945,
#  '[22.84920635]': 7.590146152568156,
#  '[23.4484127]': 6.094425727376066,
#  '[24.04761905]': 4.8050054449127515,
#  '[33.83333333]': 3.242537460925792,
#  '[45.33333333]': 9.649762091201879,
#  '[47.5]': 6.735678499468598,
#  '[47.75]': 2.4912596826709503,
#  '[49.04166667]': 4.048059651583401,
#  '[53.16666667]': 6.825387871689237,
#  '[59.83333333]': 6.5236102503103695,
#  '[34.75]': 18.406189925242977,
#  '[25.08333333]': 9.492187242197705,
#  '[41.20833333]': 5.37553144371612,
#  '[41.70833333]': 2.809006275195536,
#  '[49.41666667]': 9.073812424594543,
#  '[24.25]': 26.472523832413614,
#  '[35.71428571]': 2.5064600797863363,
#  '[43.41666667]': 9.898003064611288,
#  '[41.91666667]': 2.482613442209569,
#  '[43.54166667]': 3.347266234719946,
#  '[49.66666667]': 3.982393407165823,
#  '[56.91666667]': 5.051080760979239,
#  '[56.375]': 0.10364379565524473,
#  '[54.]': 0.31144234638515655,
#  '[52.08333333]': 3.2294509394386424,
#  '[52.15]': 1.3011615579989169,
#  '[34.33333333]': 17.633126636545782,
#  '[36.25]': 2.334505879928372,
#  '[52.33333333]': 9.250706057320166,
#  '[49.77272727]': 0.7962110472799964,
#  '[41.04166667]': 10.715586761633958,
#  '[44.83333333]': 5.7187700013033975,
#  '[51.58333333]': 7.2526599398845235,
#  '[46.375]': 1.0829175492643515,
#  '[47.625]': 0.7772608364038831,
#  '[50.]': 3.3325124020970236,
#  '[43.08333333]': 6.7890098286856,
#  '[30.75]': 13.976106780514463,
#  '[34.41666667]': 2.532318295068521,
#  '[56.45833333]': 22.424084066345877,
#  '[61.45454545]': 6.936487206502839,
#  '[59.70833333]': 3.4957874942386837,
#  '[34.79166667]': 1.5285558668263306,
#  '[38.70833333]': 1.072944635234144,
#  '[33.04166667]': 6.937385693814164,
#  '[44.20833333]': 7.595316122336897,
#  '[56.29166667]': 8.861335450827227,
#  '[65.09090909]': 11.634259477619977,
#  '[59.58333333]': 1.4588182332566788,
#  '[56.5]': 6.861193994436711,
#  '[37.16666667]': 20.438589797974295,
#  '[29.58333333]': 8.935777327301498,
#  '[38.75]': 7.308972588783174,
#  '[44.31818182]': 5.405210022956695,
#  '[56.08333333]': 7.560030594005205,
#  '[48.]': 6.1073415919933325,
#  '[29.33333333]': 15.929797011506938,
#  '[36.47826087]': 3.5127903950951165,
#  '[32.17391304]': 11.489176957299698,
#  '[35.16666667]': 1.4708713123777315,
#  '[49.58333333]': 15.04224300656356,
#  '[47.95454545]': 4.1210016904138485,
#  '[29.66666667]': 6.7218872392655875,
#  '[37.125]': 1.5613003630198747,
#  '[52.80952381]': 15.064360472300393,
#  '[47.08333333]': 5.404394642953534,
#  '[33.29166667]': 6.358658038846798,
#  '[28.16666667]': 9.288705516718277,
#  '[30.95833333]': 1.7024601747469639,
#  '[28.45833333]': 8.451370300375476,
#  '[30.16666667]': 5.478709157284268,
#  '[43.04166667]': 10.232880219055751,
#  '[31.95652174]': 9.564476056537185,
#  '[27.125]': 6.833239418202723,
#  '[36.20833333]': 3.6002898367155325,
#  '[28.875]': 14.566577693479317,
#  '[142.29166667]': 106.78879746614187,
#  '[168.04761905]': 84.9250583890996,
#  '[62.]': 27.72279631293675,
#  '[28.125]': 36.85243293916673,
#  '[31.75]': 0.8205137556423381,
#  '[35.41666667]': 7.394151454919566,
#  '[39.08333333]': 4.129053925384497,
#  '[32.04761905]': 6.914161756772735,
#  '[31.70833333]': 2.4290266965480534,
#  '[36.29166667]': 3.2321036094767877,
#  '[31.30434783]': 11.3570668446629,
#  '[54.30434783]': 19.493592580770382,
#  '[66.61111111]': 7.8725513516817145,
#  '[66.7826087]': 3.758839921641581,
#  '[44.43478261]': 18.92186444414689,
#  '[36.45833333]': 1.036045035650865,
#  '[36.5]': 4.659670447560579,
#  '[34.875]': 5.4714495436564405,
#  '[38.54166667]': 3.3195110762481193,
#  '[35.375]': 1.4125528263072198,
#  '[38.95238095]': 3.4702168991732805,
#  '[34.95833333]': 3.3780332634293657,
#  '[26.75]': 7.309511722617579,
#  '[28.]': 12.463203844409982,
#  '[34.29166667]': 1.7897825122218833,
#  '[35.45833333]': 1.3411406693014385,
#  '[40.79166667]': 4.8621152981392015,
#  '[39.75]': 1.1125737345498905,
#  '[34.83333333]': 5.355799204222258,
#  '[35.52380952]': 6.186642232104781,
#  '[38.29166667]': 3.049601188289948,
#  '[32.95833333]': 5.906256238601102,
#  '[33.40909091]': 3.6384678454237758,
#  '[33.75]': 2.8122158667964854,
#  '[27.875]': 9.027809793558951,
#  '[33.16666667]': 0.21962945501109488,
#  '[48.625]': 1.6856979959601333,
#  '[51.95833333]': 5.445116753942251,
#  '[43.20833333]': 4.72542840899677,
#  '[34.20833333]': 9.825465491015947,
#  '[39.625]': 1.100634640934004,
#  '[39.]': 0.9479322724673551,
#  '[36.41666667]': 1.7444616370469817,
#  '[50.83333333]': 10.994972628599825,
#  '[52.81818182]': 5.3630533857743,
#  '[51.83333333]': 0.10860003823847819,
#  '[47.45833333]': 0.6333045417875738,
#  '[48.69565217]': 2.9477354800977977,
#  '[37.91666667]': 9.546301575088023,
#  '[37.70833333]': 0.8785073565186465,
#  '[38.]': 0.23170420567272032}

# %%
p = {'n_estimators': 585,
 'min_samples_split': 2,
 'min_samples_leaf': 8,
 'max_depth': 52,
 'bootstrap': True}

# %%
model_forest_n = RandomForestRegressor(random_state=42,**p)

# %%
df_aqi_daily.tail(1)
# Out:
#                              CO_avg  CO_SubIndex   PM10_avg  PM10_SubIndex  \
# Datetime
# 2022-05-19 00:00:00+01:00  0.255324          3.0  19.817325           18.4
#
#                             NO2_avg  NO2_SubIndex   SO2_avg  SO2_SubIndex  \
# Datetime
# 2022-05-19 00:00:00+01:00  8.679635      8.333333  0.763347           1.0
#
#                             O3_avg  O3_SubIndex  PM2.5_avg  PM2.5_SubIndex  \
# Datetime
# 2022-05-19 00:00:00+01:00  0.03618         33.4   8.917787            37.4
#
#                             AQI
# Datetime
# 2022-05-19 00:00:00+01:00  38.0
