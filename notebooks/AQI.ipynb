# %%
import sys
sys.version
# Out:
# '3.9.12 (main, Apr  5 2022, 01:53:17) \n[Clang 12.0.0 ]'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
country = 'ES'

# %%
df_co = pd.read_csv(f"../data/interim/cleaned/{country}_CO_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
df_co
# Out:
#                           Countrycode    Namespace AirQualityNetwork  \
# Datetime
# 2020-01-01 01:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2020-01-01 02:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2020-01-01 03:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2020-01-01 04:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2020-01-01 05:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# ...                               ...          ...               ...
# 2022-06-02 07:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-06-02 08:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-06-02 09:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-06-02 10:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-06-02 11:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
#
#                           AirQualityStationEoICode     SamplingPoint  \
# Datetime
# ...

# %%
fig = plt.figure(figsize=(15, 10))
df_co["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_no2 = pd.read_csv(f"../data/interim/cleaned/{country}_NO2_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_no2["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_o3 = pd.read_csv(f"../data/interim/cleaned/{country}_O3_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_o3["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_so2 = pd.read_csv(f"../data/interim/cleaned/{country}_SO2_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_so2["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_pm10 = pd.read_csv(f"../data/interim/cleaned/{country}_PM10_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_pm10["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_pm25 = pd.read_csv(f"../data/interim/cleaned/{country}_PM2.5_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_pm25["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_pm25["Concentration"].idxmax()
# Out:
# Timestamp('2020-11-06 13:00:00+0100', tz='pytz.FixedOffset(60)')

# %%
df_pm10["Concentration"].idxmax()
# Out:
# Timestamp('2022-03-15 09:00:00+0100', tz='pytz.FixedOffset(60)')

# %% [markdown]
# AQI

# %%
df_aqi = pd.read_csv("../data/processed/AQI_dataset.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_aqi["AQI"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_aqi_daily = df_aqi.resample('D').mean().interpolate()
fig = plt.figure(figsize=(15, 10))
df_aqi_daily["AQI"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %% [markdown]
# ***Time series analysis***

# %% [markdown]
# Stationarity

# %%
from statsmodels.tsa.stattools import adfuller
ADF_result = adfuller(df_aqi_daily["AQI"])   
print(f'ADF Statistic: {ADF_result[0]}') 
print(f'p-value: {ADF_result[1]}')
# Out:
# ADF Statistic: -10.869053097432937
# p-value: 1.383425557559172e-19

# %% [markdown]
# With a large negative ADF statistic and a p-value much smaller than 0.05, we can say that our series is stationary.

# %% [markdown]
# Autocorrelation

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(df_aqi_daily["AQI"], lags=50)
plt.tight_layout()

# %%
plot_pacf(df_aqi_daily["AQI"], lags=50)
plt.show()
# Out:
# /home/icelandic/.cache/pypoetry/virtualenvs/mlops-project-UMt4i_ZD-py3.9/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Negative spikes every 7 lags

# %% [markdown]
# Looks like autoregressive process

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

analysis = df_aqi_daily["AQI"].copy()


decompose_result_mult = seasonal_decompose(analysis, model="multiplicative")

trend = decompose_result_mult.trend
seasonal = decompose_result_mult.seasonal
residual = decompose_result_mult.resid

fig = plt.figure(figsize=(15, 10))
seasonal[:10].plot();

# %% [markdown]
# Looks like there is weekly seasonality

# %% [markdown]
# ***Baseline Naive Algorithm***

# %%
pd.concat([df_aqi_daily["AQI"].shift(1), df_aqi_daily["AQI"]], axis=1).dropna()
# Out:
#                                  AQI        AQI
# Datetime
# 2020-01-02 00:00:00+01:00  89.739130  76.208333
# 2020-01-03 00:00:00+01:00  76.208333  85.375000
# 2020-01-04 00:00:00+01:00  85.375000  81.791667
# 2020-01-05 00:00:00+01:00  81.791667  41.708333
# 2020-01-06 00:00:00+01:00  41.708333  59.916667
# ...                              ...        ...
# 2022-05-29 00:00:00+01:00  38.166667  48.625000
# 2022-05-30 00:00:00+01:00  48.625000  44.875000
# 2022-05-31 00:00:00+01:00  44.875000  39.409091
# 2022-06-01 00:00:00+01:00  39.409091  40.000000
# 2022-06-02 00:00:00+01:00  40.000000  37.500000
#
# [883 rows x 2 columns]

# %%
values = pd.DataFrame(df_aqi_daily["AQI"].values)
df_naive = pd.concat([values.shift(1), values], axis=1).dropna()
df_naive.columns = ['t-1', 't+1']
df_naive
# Out:
#            t-1        t+1
# 1    89.739130  76.208333
# 2    76.208333  85.375000
# 3    85.375000  81.791667
# 4    81.791667  41.708333
# 5    41.708333  59.916667
# ..         ...        ...
# 879  38.166667  48.625000
# 880  48.625000  44.875000
# 881  44.875000  39.409091
# 882  39.409091  40.000000
# 883  40.000000  37.500000
#
# [883 rows x 2 columns]

# %% [markdown]
# For 5 days Naive

# %%
train, test = df_naive[1:-5], df_naive[-5:]
train_X, train_y = train["t-1"], train["t+1"]
test_X, test_y = test["t-1"], test["t+1"]

# %%
predictions = test_X.apply(lambda x: x)
test_rmse = mean_squared_error(test_y, predictions, squared=False)
print('Test RMSE: %.3f' % test_rmse)
# Out:
# Test RMSE: 5.655

# %% [markdown]
# For 20% test size

# %%
train_size = int(df_naive.shape[0] * 0.75)
train, test = df_naive[1:train_size], df_naive[train_size:]
train_X, train_y = train["t-1"], train["t+1"]
test_X, test_y = test["t-1"], test["t+1"]

# %%
predictions = test_X.apply(lambda x: x)
test_rmse = mean_squared_error(test_y, predictions, squared=False)
print('Test RMSE: %.3f' % test_rmse)
# Out:
# Test RMSE: 14.341

# %%
fig = plt.figure(figsize=(15, 10))
plt.plot(test_y.iloc[:])
plt.plot(predictions[:])
plt.show()

# %%
df_aqi_daily["AQI"].mean(), df_aqi_daily["AQI"].std(), df_aqi_daily["AQI"].median()
# Out:
# (45.828011182759425, 16.238174670153402, 42.62280701754386)

# %% [markdown]
# ***One more model with several list of params***

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df_aqi_daily["AQI"], test_size=0.2, shuffle=False)

# %%
model = SARIMAX(train, order=(2,0,0), seasonal_order=(1,1,1,7))
model_fit = model.fit(max_iter=50, method='powell')
print(model_fit.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 3.708528
#          Iterations: 4
#          Function evaluations: 242
#                                       SARIMAX Results
# ...
# Dep. Variable:                                 AQI   No. Observations:                  707
# Model:             SARIMAX(2, 0, 0)x(1, 1, [1], 7)   Log Likelihood               -2621.929
# Date:                             Mon, 06 Jun 2022   AIC                           5253.859
# Time:                                     20:35:16   BIC                           5276.614
# Sample:                                 01-01-2020   HQIC                          5262.655
#                                       - 12-07-2021
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
predictions_p_ms = model_fit.predict(start=len(train), end=len(train)+5)

# %%
arima_test_rmse = mean_squared_error(test.iloc[:6], predictions_p_ms, squared=False)
print('Test RMSE: %.3f' % arima_test_rmse)
# Out:
# Test RMSE: 13.826

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
train_size = int(df_naive.shape[0] * 0.75)
train, test = df_naive[1:train_size], df_naive[train_size:]
train_X, train_y = train["t-1"], train["t+1"]
test_X, test_y = test["t-1"], test["t+1"]

# %%
model_forest = RandomForestRegressor(n_estimators=1000)
model_forest.fit(train_X.values.reshape(-1, 1), train_y.values)

y_hat = model_forest.predict(np.array(test_X)[:, np.newaxis])

forest_test_rmse = mean_squared_error(test_y, y_hat, squared=False)

# %%
print(forest_test_rmse)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train["t-1"], label='training')
plt.plot(test["t-1"], label='actual')
plt.plot(test.index, y_hat, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# 13.730631358835486

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
tscv = TimeSeriesSplit()
TimeSeriesSplit(max_train_size=None, n_splits=5)
rmse = []
for train_index, test_index in tscv.split(df_naive):
    train_cv, test_cv = df_naive.iloc[train_index], df_naive.iloc[test_index]
    train_X_cv, train_y_cv = train_cv["t-1"], train_cv["t+1"]
    test_X_cv, test_y_cv = test_cv["t-1"], test_cv["t+1"]  
    
    model_forest_cv = RandomForestRegressor(n_estimators=1000)
    model_forest_cv.fit(train_X_cv.values.reshape(-1, 1), train_y_cv.values)

    y_hat_cv = model_forest_cv.predict(np.array(test_X_cv)[:, np.newaxis])

    rmse_cv = mean_squared_error(test_y_cv, y_hat_cv, squared=False)  
    rmse.append(rmse_cv)
    
    plt.figure(figsize=(12,5), dpi=100)
    plt.plot(train_cv["t-1"], label='training')
    plt.plot(test_cv["t-1"], label='actual')
    plt.plot(test_X_cv.index, y_hat_cv, label='forecast')
    plt.title('Forecast vs Actuals')
    plt.legend(loc='upper left', fontsize=8)
    plt.show()

print("RMSE: {}".format(np.mean(rmse)))
# Out:
# RMSE: 12.25566935341043

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 15)]
max_depth = [int(x) for x in np.linspace(10, 110, num = 15)]
max_depth.append(None)
min_samples_split = [2, 5, 8, 10]
min_samples_leaf = [2, 4, 6, 8]
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
tscv = TimeSeriesSplit(n_splits=3)
model_forest_cv = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = model_forest_cv, param_distributions = random_grid, 
                               n_iter = 500, cv = tscv, verbose=1, random_state=42, n_jobs = -1)

rf_random.fit(df_naive["t-1"].values.reshape(-1, 1), df_naive["t+1"].values)
# Out:
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                    estimator=RandomForestRegressor(), n_iter=500, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 17, 24, 31, 38, 45,
#                                                       52, 60, 67, 74, 81, 88,
#                                                       95, 102, 110, None],
#                                         'min_samples_leaf': [2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 8, 10],
#                                         'n_estimators': [200, 328, 457, 585,
#                                                          714, 842, 971, 1100,
#                                                          1228, 1357, 1485, 1614,
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 585,
#  'min_samples_split': 2,
#  'min_samples_leaf': 8,
#  'max_depth': 52,
#  'bootstrap': True}

# %%
best_random = rf_random.best_estimator_
predictions = best_random.predict(np.array(test_X)[:, np.newaxis])
best_rmse = mean_squared_error(test_y, predictions, squared=False)

# %%
best_rmse
# Out:
# 12.39850863221307

# %%
params = {'n_estimators': 1000,
              'min_samples_split': 2,
              'min_samples_leaf': 8,
              'max_depth': 52,
              'bootstrap': True}

# %%
df_naive.tail(1)
# Out:
#            t-1   t+1
# 869  37.708333  38.0

# %%
rmse_f = {}
n = 1
train_n, test_n = df_naive[1:train_size], df_naive[train_size:]
for i in range(len(test)):
    train_X_n, train_y_n = train_n["t-1"], train_n["t+1"]
    test_X_n, test_y_n = test_n["t-1"], test_n["t+1"]
    model_forest_n = RandomForestRegressor(random_state=42, **params)
    model_forest_n.fit(train_X_n.values.reshape(-1, 1), train_y_n.values)
    y_hat_n = model_forest_n.predict(np.array(test_X_n.iloc[i:i+n])[:, np.newaxis])
    rmse_n = mean_squared_error(test_y_n.iloc[i:i+n], y_hat_n, squared=False)  
    rmse_f[f'{test_y_n.iloc[i:i+n].values}'] = rmse_n
    
    train_n = pd.concat([train_n, test_n.iloc[i:i+n]])

# print("RMSE: {}".format(np.mean(rmse_f)))

# %%
p = {'n_estimators': 585,
 'min_samples_split': 2,
 'min_samples_leaf': 8,
 'max_depth': 52,
 'bootstrap': True}

# %%
model_forest_n = RandomForestRegressor(random_state=42,**p)

# %%
df_aqi_daily.tail(1)
# Out:
#                              CO_avg  CO_SubIndex   PM10_avg  PM10_SubIndex  \
# Datetime
# 2022-05-19 00:00:00+01:00  0.255324          3.0  19.817325           18.4
#
#                             NO2_avg  NO2_SubIndex   SO2_avg  SO2_SubIndex  \
# Datetime
# 2022-05-19 00:00:00+01:00  8.679635      8.333333  0.763347           1.0
#
#                             O3_avg  O3_SubIndex  PM2.5_avg  PM2.5_SubIndex  \
# Datetime
# 2022-05-19 00:00:00+01:00  0.03618         33.4   8.917787            37.4
#
#                             AQI
# Datetime
# 2022-05-19 00:00:00+01:00  38.0

# %% [markdown]
# Experiments with model arguments amount

# %%
pd.concat([df_aqi_daily['AQI'], df_aqi_daily['AQI'].shift(1).rename('prev')], axis=1)
# Out:
#                                  AQI       prev
# Datetime
# 2020-01-01 00:00:00+01:00  89.739130        NaN
# 2020-01-02 00:00:00+01:00  76.208333  89.739130
# 2020-01-03 00:00:00+01:00  85.375000  76.208333
# 2020-01-04 00:00:00+01:00  81.791667  85.375000
# 2020-01-05 00:00:00+01:00  41.708333  81.791667
# ...                              ...        ...
# 2022-05-26 00:00:00+01:00  36.500000  35.500000
# 2022-05-27 00:00:00+01:00  29.666667  36.500000
# 2022-05-28 00:00:00+01:00  39.181818  29.666667
# 2022-05-29 00:00:00+01:00  48.625000  39.181818
# 2022-05-30 00:00:00+01:00  50.666667  48.625000
#
# [881 rows x 2 columns]

# %%
[x for x in df_aqi_daily.columns if 'avg' in x]
# Out:
# ['CO_avg', 'PM10_avg', 'NO2_avg', 'SO2_avg', 'O3_avg', 'PM2.5_avg']

# %%
depth = 1
cols = ['CO_avg', 'PM10_avg', 'NO2_avg', 'SO2_avg', 'O3_avg', 'PM2.5_avg']

y = df_aqi_daily['AQI'].copy()
x_list = [df_aqi_daily[cols].shift(i) for i in range(1, depth+1)]
x = pd.concat(x_list, axis=1)

x = x.iloc[depth:]
y = y.iloc[depth:]

X_train, X_test, y_train, y_test = train_test_split(x, y, shuffle=False, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((660, 6), (220, 6), (660,), (220,))

# %%
X_train.head()
# Out:
#                              CO_avg   PM10_avg    NO2_avg   SO2_avg    O3_avg  \
# Datetime
# 2020-01-02 00:00:00+01:00  0.536474  39.943001  22.180433  0.862914  0.004654
# 2020-01-03 00:00:00+01:00  0.620125  32.661458  27.433846  0.842862  0.002449
# 2020-01-04 00:00:00+01:00  0.645130  42.541667  25.374647  0.477092  0.002210
# 2020-01-05 00:00:00+01:00  0.472822  33.244792  23.381874  0.588413  0.009893
# 2020-01-06 00:00:00+01:00  0.519650  15.076389  23.160454  0.747444  0.007739
#
#                            PM2.5_avg
# Datetime
# 2020-01-02 00:00:00+01:00  30.075339
# 2020-01-03 00:00:00+01:00  24.017361
# 2020-01-04 00:00:00+01:00  28.421875
# 2020-01-05 00:00:00+01:00  26.777778
# 2020-01-06 00:00:00+01:00   9.965278

# %%
model_forest = RandomForestRegressor(**{'n_estimators': 585,
 'min_samples_split': 2,
 'min_samples_leaf': 8,
 'max_depth': 52,
 'bootstrap': True})

model_forest.fit(X_train, y_train)

y_hat = model_forest.predict(X_test)

forest_test_rmse = mean_squared_error(y_test, y_hat, squared=False) 
forest_test_rmse
# Out:
# 13.165083321714807

# %%
cols = ["AQI"]
for depth in range(1, 30):
    y = df_aqi_daily['AQI'].copy()
    x_list = [df_aqi_daily[cols].shift(i) for i in range(1, depth+1)]
    x = pd.concat(x_list, axis=1)

    x = x.iloc[depth:]
    y = y.iloc[depth:]

    X_train, X_test, y_train, y_test = train_test_split(x, y, shuffle=False, random_state=42)
    model_forest = RandomForestRegressor(**{'n_estimators': 585,
     'min_samples_split': 2,
     'min_samples_leaf': 8,
     'max_depth': 52,
     'bootstrap': True})

    model_forest.fit(X_train, y_train)

    y_hat = model_forest.predict(X_test)

    forest_test_rmse = mean_squared_error(y_test, y_hat, squared=False) 
    print(depth, forest_test_rmse)
# Out:
# 1 13.17292993905297
# 2 13.416926923730749
# 3 13.347682095113962
# 4 13.27062432886198
# 5 13.22924930895555
# 6 13.280102605647222
# 7 13.21641557413936
# 8 13.24055224622286
# 9 13.27136334947271
# 10 13.287903447666638
# 11 13.276272432725916
# 12 13.272038152208093
# 13 13.296982163965817
# 14 13.305869326834483
# 15 13.300175957549719
# 16 13.251530351862154
# 17 13.211108395175662
# 18 13.229088472732458
# 19 13.228985374866376
# 20 13.283760770432206
# 21 13.234630536751858
# 22 13.247743231417678
# 23 13.217433252165565
# 24 13.18093504580896
# 25 13.156407228689746
# 26 13.122650389635169
# 27 13.12608075601548
# 28 13.226778400114728
# 29 13.204193881191319

# %%
cols = ['CO_avg', 'PM10_avg', 'NO2_avg', 'SO2_avg', 'O3_avg', 'PM2.5_avg']
for depth in range(1, 30):
    y = df_aqi_daily['AQI'].copy()
    x_list = [df_aqi_daily[cols].shift(i) for i in range(1, depth+1)]
    x = pd.concat(x_list, axis=1)

    x = x.iloc[depth:]
    y = y.iloc[depth:]

    X_train, X_test, y_train, y_test = train_test_split(x, y, shuffle=False, random_state=42)
    model_forest = RandomForestRegressor(**{'n_estimators': 585,
     'min_samples_split': 2,
     'min_samples_leaf': 8,
     'max_depth': 52,
     'bootstrap': True})

    model_forest.fit(X_train, y_train)

    y_hat = model_forest.predict(X_test)

    forest_test_rmse = mean_squared_error(y_test, y_hat, squared=False) 
    print(depth, forest_test_rmse)
# Out:
# 1 13.548496566311208
# 2 13.030894753554172
# 3 13.03964895655481
# 4 12.908835087324036
# 5 12.883912007572492
# 6 12.811782917778624
# 7 12.776405685897675
# 8 12.824455995368925
# 9 12.716838267930514
# 10 12.723195963328724
# 11 12.741570872909582
# 12 12.735196216008404
# 13 12.659015073355548
# 14 12.636168421043722
# 15 12.654270563484085
# 16 12.599782050197797
# 17 12.61033131357648
# 18 12.613833227058882
# 19 12.680366410157896
# 20 12.700842488554185
# 21 12.731551489712212
# 22 12.73010027978415
# 23 12.681568622724845
# 24 12.623549664893629
# 25 12.649043592162842
# 26 12.671443850184284
# 27 12.647784416440567
# 28 12.638614772223113
# 29 12.701724504729995

# %%
from xgboost import XGBRegressor

# %%
cols = ['CO_avg', 'PM10_avg', 'NO2_avg', 'SO2_avg', 'O3_avg', 'PM2.5_avg']
for depth in range(1, 30):
    y = df_aqi_daily['AQI'].copy()
    x_list = [df_aqi_daily[cols].shift(i) for i in range(1, depth+1)]
    x = pd.concat(x_list, axis=1)
    x.columns = list(range(len(x.columns)))

    x = x.iloc[depth:]
    y = y.iloc[depth:]

    X_train, X_test, y_train, y_test = train_test_split(x, y, shuffle=False, random_state=42)
    model_forest = XGBRegressor()

    model_forest.fit(X_train, y_train)

    y_hat = model_forest.predict(X_test)

    forest_test_rmse = mean_squared_error(y_test, y_hat, squared=False) 
    print(depth, forest_test_rmse)
# Out:
# 1 14.438755973666003
# 2 13.378858107588789
# 3 13.869310060623816
# 4 14.604306954701249
# 5 13.183028802911522
# 6 12.92195695581464
# 7 14.171824752909268
# 8 14.058196524625071
# 9 13.211863430403334
# 10 13.329637835842966
# 11 12.86097703291059
# 12 13.895359866339389
# 13 13.015696506717697
# 14 12.636056255950722
# 15 13.412579188829586
# 16 12.560086746732193
# 17 12.478855886073886
# 18 12.96159932418661
# 19 12.438766715539453
# 20 13.22651526994497
# 21 13.142737561635423
# 22 12.946631654826273
# 23 12.995392569950312
# 24 12.486516227285637
# 25 13.443561420606247
# 26 14.238298264831336
# 27 13.854253975922513
# 28 13.479709556596529
# 29 13.379258314484812

# %%
cols = ["AQI"]
for depth in range(1, 30):
    y = df_aqi_daily['AQI'].copy()
    x_list = [df_aqi_daily[cols].shift(i) for i in range(1, depth+1)]
    x = pd.concat(x_list, axis=1)
    x.columns = list(range(len(x.columns)))

    x = x.iloc[depth:]
    y = y.iloc[depth:]

    X_train, X_test, y_train, y_test = train_test_split(x, y, shuffle=False, random_state=42)
    model_forest = XGBRegressor()

    model_forest.fit(X_train, y_train)

    y_hat = model_forest.predict(X_test)

    forest_test_rmse = mean_squared_error(y_test, y_hat, squared=False) 
    print(depth, forest_test_rmse)
# Out:
# 1 13.568144956346998
# 2 13.991284470831433
# 3 14.131628412036408
# 4 14.231081925803867
# 5 14.078395310635885
# 6 13.833894432349894
# 7 14.285467004396603
# 8 14.05460862848906
# 9 14.288295857201794
# 10 14.19671646551197
# 11 13.577358897554216
# 12 14.194105762306446
# 13 13.935009255501317
# 14 14.138636020627178
# 15 13.724763949844652
# 16 13.36011273123336
# 17 13.24524359325794
# 18 13.605461893581108
# 19 13.589902088612734
# 20 13.272731344248
# 21 13.461741623065887
# 22 13.01183929118328
# 23 13.149688772251766
# 24 13.514058473527147
# 25 12.628604192073109
# 26 13.473640844698684
# 27 13.022158251941004
# 28 13.78425183196219
# 29 13.106437554641593

# %%
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 15)]
max_depth = [int(x) for x in np.linspace(10, 110, num = 15)]
max_depth.append(None)
min_samples_split = [2, 5, 8, 10]
min_samples_leaf = [2, 4, 6, 8]
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
cols = ['CO_avg', 'PM10_avg', 'NO2_avg', 'SO2_avg', 'O3_avg', 'PM2.5_avg']
depth = 16
y = df_aqi_daily['AQI'].copy()
x_list = [df_aqi_daily[cols].shift(i) for i in range(1, depth+1)]
x = pd.concat(x_list, axis=1)

x = x.iloc[depth:]
y = y.iloc[depth:]

tscv = TimeSeriesSplit(n_splits=3)
model_forest_cv = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = model_forest_cv, param_distributions = random_grid, 
                               n_iter = 500, cv = tscv, verbose=1, random_state=42, n_jobs = -1)

rf_random.fit(x, y)
rf_random.best_estimator_
# Out:
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# RandomForestRegressor(max_depth=17, min_samples_leaf=4, min_samples_split=8,
#                       n_estimators=457)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, shuffle=False, random_state=42)
best_random = rf_random.best_estimator_
predictions = best_random.predict(X_test)
best_rmse = mean_squared_error(y_test, predictions, squared=False)  
best_rmse
# Out:
# 8.568303980630455

# %%
RandomForestRegressor(max_depth=17, min_samples_leaf=4, min_samples_split=8,
                      n_estimators=457)

# %%
import warnings
warnings.filterwarnings('ignore')
cols = ['CO_avg', 'PM10_avg', 'NO2_avg', 'SO2_avg', 'O3_avg', 'PM2.5_avg']
depth = 16
y = df_aqi_daily['AQI'].copy()
x_list = [df_aqi_daily[cols].shift(i) for i in range(1, depth+1)]
x = pd.concat(x_list, axis=1)
x.columns = [i for i in range(0, x.shape[1])]

x = x.iloc[depth:]
y = y.iloc[depth:]
params_xgb = {
    'n_estimators':[100, 500, 1000],
    'min_child_weight':[4,5],
    'gamma':[i/10.0 for i in range(3,6)],  
    'subsample':[i/10.0 for i in range(6,11)],
    'colsample_bytree':[i/10.0 for i in range(6,11)], 
    'max_depth': [2,3,4,6,7],
    'objective': ['reg:squarederror', 'reg:tweedie'],
    'booster': ['gbtree', 'gblinear'],
    'eval_metric': ['rmse'],
    'eta': [i/10.0 for i in range(3,6)],
}
model_xgb_cv = XGBRegressor()
xgb_random = RandomizedSearchCV(estimator = model_xgb_cv, param_distributions = params_xgb, 
                               n_iter = 500, cv = tscv, verbose=1, random_state=42, n_jobs = -1)

xgb_random.fit(x, y)
xgb_random.best_estimator_
# Out:
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# [14:35:38] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight", "subsample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [14:35:38] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight", "subsample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [14:35:39] WARNING: ../src/learner.cc:627:
# ...

# %%
best_random_xgb = xgb_random.best_estimator_
predictions_xgb = best_random_xgb.predict(X_test)
best_rmse_xgb = mean_squared_error(y_test, predictions_xgb, squared=False)  
best_rmse_xgb
# Out:
# 3.190800648953614
# [14:51:18] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight", "subsample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [14:51:19] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight", "subsample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [14:51:19] WARNING: ../src/learner.cc:627:
# ...
