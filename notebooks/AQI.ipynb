# %%
import sys
sys.version
# Out:
# '3.9.12 (main, May  5 2022, 20:10:55) \n[GCC 7.5.0]'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_co = pd.read_csv("../data/interim/cleaned/ES_CO_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
df_co
# Out:
#                           Countrycode    Namespace AirQualityNetwork  \
# Datetime
# 2021-01-01 02:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2021-01-01 03:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2021-01-01 04:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2021-01-01 05:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2021-01-01 06:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# ...                               ...          ...               ...
# 2022-05-13 05:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-05-13 06:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-05-13 07:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-05-13 08:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
# 2022-05-13 09:00:00+01:00          ES  ES.BDCA.AQD        NET_ES213A
#
#                           AirQualityStationEoICode     SamplingPoint  \
# Datetime
# ...

# %%
fig = plt.figure(figsize=(15, 10))
sns.scatterplot(data=df_co, x="Datetime", y="Concentration")
# Out:
# <AxesSubplot:xlabel='Datetime', ylabel='Concentration'>

# %%
fig = plt.figure(figsize=(15, 10))
df_co["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_no2 = pd.read_csv("../data/interim/cleaned/ES_NO2_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_no2["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_o3 = pd.read_csv("../data/interim/cleaned/ES_O3_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_o3["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_so2 = pd.read_csv("../data/interim/cleaned/ES_SO2_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_so2["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_pm10 = pd.read_csv("../data/interim/cleaned/ES_PM10_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_pm10["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_pm25 = pd.read_csv("../data/interim/cleaned/ES_PM2.5_cleaned.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_pm25["Concentration"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df_pm25["Concentration"].idxmax()
# Out:
# Timestamp('2022-03-15 09:00:00+0100', tz='pytz.FixedOffset(60)')

# %%
df_pm10["Concentration"].idxmax()
# Out:
# Timestamp('2022-03-15 09:00:00+0100', tz='pytz.FixedOffset(60)')

# %% [markdown]
# AQI

# %%
df_aqi = pd.read_csv("../data/processed/AQI_dataset.csv", parse_dates=['Datetime'], index_col=['Datetime'])
fig = plt.figure(figsize=(15, 10))
df_aqi["AQI"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %% [markdown]
# Check stationarity and so on

# %% [markdown]
# Baseline

# %% [markdown]
# One more model with several list of params
